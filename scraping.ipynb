# %%
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-sllhkfo8
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-sllhkfo8
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 786815dd05681e2421cd03aa9acf5ab5c773bce9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for snscrape: filename=snscrape-0.6.2.20230321.dev13+g786815d-py3-none-any.whl size=73302 sha256=704fb9358ed438d995b40c8e126e64bfed85a624f773a2bc8bca121c7a92ed6a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-asopifm4/wheels/05/e9/f7/57056e7c7e44b1feed932fa49fdec9d706c4f563e37160ab74
# Successfully built snscrape
# ...

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"kadrun"').get_items(), 400))

df.head(20)
# Out:
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1599815537210564610-18ddfb12d11616e3'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1655430901394812930-18dd27528cc039e9'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1658882068162412559-18dd1fc5bceb6064'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1599815537210564610-18dd2387043c73e9'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1655430901394812930-18dd50cecb6f8ea3'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1658882068162412559-18dd86f5a4224298'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1657862615689773060-18ddbba40e4e1637'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1599815537210564610-18dd6b9092f26085'
# ...

# %%
df.count()
# Out:
# url                 400
# date                400
# rawContent          400
# renderedContent     400
# id                  400
# user                400
# replyCount          400
# retweetCount        400
# likeCount           400
# quoteCount          400
# conversationId      400
# lang                400
# source                0
# sourceUrl             0
# sourceLabel           0
# links                 6
# media                53
# retweetedTweet        0
# quotedTweet          18
# inReplyToTweetId    371
# inReplyToUser       371
# mentionedUsers      373
# coordinates           0
# place                 0
# hashtags              2
# cashtags              0
# card                  4
# viewCount           383
# vibe                  0
# bookmarkCount       400
# dtype: int64

# %%
data2 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper('"vincent desta"').get_items(), 400))

data2
# Out:
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1633316742301614080-18e2fb45e92c9e0b'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1599815537210564610-18e2aa8dce3d6467'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1658882068200161280-18e246d276922cc6'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1599815537210564610-18e2224d3511445c'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1658882068162412559-18e29e54268c3953'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1599815537407803393-18e2c509ad15f484'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1658882068162412559-18e221922e185844'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1633316742301614080-18e27a4d93018cd1'
# ...

# %%
data2.count()
# Out:
# url                 400
# date                400
# rawContent          400
# renderedContent     400
# id                  400
# user                400
# replyCount          400
# retweetCount        400
# likeCount           400
# quoteCount          400
# conversationId      400
# lang                400
# source                0
# sourceUrl             0
# sourceLabel           0
# links                49
# media                91
# retweetedTweet        0
# quotedTweet          64
# inReplyToTweetId    171
# inReplyToUser       171
# mentionedUsers      170
# coordinates           4
# place                 4
# hashtags             37
# cashtags              0
# card                 25
# viewCount           400
# vibe                  0
# bookmarkCount       400
# dtype: int64

# %%
data2.to_csv('data0.3.csv', index = False)

# %%
#data2.to_excel('dara2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5eb349a7962e> in <cell line: 1>()
# ----> 1 data2.to_excel('dara2.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...
